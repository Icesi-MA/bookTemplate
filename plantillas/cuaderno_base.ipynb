# %% [markdown]
# # [Jornada o tema] - [Título del cuaderno]
#
# **Curso:** [Nombre del curso]
# **Docente:** [Nombre del docente]
# **Semestre:** [AAAA-I / AAAA-II]
# **Resultado de aprendizaje:** [Qué podrá hacer el estudiante al finalizar]

# %% [markdown]
# ## Objetivos
#
# - [Objetivo 1]
# - [Objetivo 2]
# - [Objetivo 3]

# %% [markdown]
# ## Conceptos previos
#
# - [Concepto previo 1]
# - [Concepto previo 2]
# - [Lectura o recurso recomendado]

# %% [markdown]
# ## Problema guía
#
# Describe el problema aplicado que organizará la sesión. Incluye contexto, variables, supuestos y una pregunta concreta.
#
# $$
# M(x) = ...
# $$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Desarrollo
#
# Explica el método, procedimiento o razonamiento matemático. Combina texto, ecuaciones y código reproducible.

# %%
# Escribe aquí el código principal de la jornada.

# %% [markdown]
# ## Actividad
#
# 1. [Instrucción 1]
# 2. [Instrucción 2]
# 3. [Producto esperado]

# %% [markdown]
# ## Cierre
#
# - Conclusión principal:
# - Limitación del modelo o método:
# - Pregunta para continuar:

# %% [markdown]
# ## Referencias
#
# - [Referencia 1]
# - [Referencia 2]
